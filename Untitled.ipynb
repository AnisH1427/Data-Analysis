# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
from scipy import stats as st
import math

# %%
from IPython.display import display
import pandas as pd
path = 'data/diabetes.csv'
count=0
for chunk in pd.read_csv(path, chunksize=5):
    # Do something with the chunk
    if(count<5):
        display(chunk)
    count+=1
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  Age  \
# 0            6      148             72             35        0  33.6   50
# 1            1       85             66             29        0  26.6   31
# 2            8      183             64              0        0  23.3   32
# 3            1       89             66             23       94  28.1   21
# 4            0      137             40             35      168  43.1   33
#
#    DiabetesPedigreeFunction
# 0                     0.627
# 1                     0.351
# 2                     0.672
# 3                     0.167
# 4                     2.288
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  Age  \
# 5            5      116             74              0        0  25.6   30
# 6            3       78             50             32       88  31.0   26
# 7           10      115              0              0        0  35.3   29
# ...

# %%
df = pd.read_csv(path)

# %%
df.shape
# Out:
# (768, 8)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 8 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   Age                       768 non-null    int64
#  7   DiabetesPedigreeFunction  768 non-null    float64
# dtypes: float64(2), int64(6)
# memory usage: 48.1 KB

# %%
df.nunique()
# Out:
# Pregnancies                 17
# Glucose                    136
# BloodPressure               47
# SkinThickness               51
# Insulin                    186
# BMI                        248
# Age                         52
# Diabetes Pedigree Index    517
# dtype: int64

# %%
df.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# Age                         0
# DiabetesPedigreeFunction    0
# dtype: int64

# %%
df.rename(columns={"DiabetesPedigreeFunction" :"Diabetes Pedigree Index"},inplace=True)

# %%
df.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'Age', 'Diabetes Pedigree Index'],
#       dtype='object')

# %%
df.describe().T
# Out:
#                          count        mean         std     min       25%  \
# Pregnancies              768.0    3.845052    3.369578   0.000   1.00000
# Glucose                  768.0  120.894531   31.972618   0.000  99.00000
# BloodPressure            768.0   69.105469   19.355807   0.000  62.00000
# SkinThickness            768.0   20.536458   15.952218   0.000   0.00000
# Insulin                  768.0   79.799479  115.244002   0.000   0.00000
# BMI                      768.0   31.992578    7.884160   0.000  27.30000
# Age                      768.0   33.240885   11.760232  21.000  24.00000
# Diabetes Pedigree Index  768.0    0.471876    0.331329   0.078   0.24375
#
#                               50%        75%     max
# Pregnancies                3.0000    6.00000   17.00
# Glucose                  117.0000  140.25000  199.00
# BloodPressure             72.0000   80.00000  122.00
# SkinThickness             23.0000   32.00000   99.00
# ...

# %%
for each_columns in df.columns:
    print("Mode of {} : {}".format(each_columns,statistics.mode(df[each_columns])))
    print("Median of {} : {}".format(each_columns,np.median(df[each_columns])))
    print("Average of {} : {}".format(each_columns,np.mean(df[each_columns])))
# Out:
# Mode of Pregnancies : 1
# Median of Pregnancies : 3.0
# Average of Pregnancies : 3.8450520833333335
# Mode of Glucose : 100
# Median of Glucose : 117.0
# Average of Glucose : 120.89453125
# Mode of BloodPressure : 70
# Median of BloodPressure : 72.0
# Average of BloodPressure : 69.10546875
# Mode of SkinThickness : 0
# Median of SkinThickness : 23.0
# Average of SkinThickness : 20.536458333333332
# Mode of Insulin : 0
# Median of Insulin : 30.5
# Average of Insulin : 79.79947916666667
# Mode of BMI : 32.0
# Median of BMI : 32.0
# Average of BMI : 31.992578124999998
# Mode of Age : 22
# Median of Age : 29.0
# Average of Age : 33.240885416666664
# Mode of Diabetes Pedigree Index : 0.254
# Median of Diabetes Pedigree Index : 0.3725
# Average of Diabetes Pedigree Index : 0.47187630208333325

# %%
# A simple scatter plot with Matplotlib
ax = plt.axes()

ax.scatter(df.BMI,df["Diabetes Pedigree Index"])

# Label the axes
ax.set(xlabel='BMI',
       ylabel='DPI',
       title='BMI vs DPI');
### END SOLUTION

# %%
df.sort_values(by = 'BMI', ascending = False)[:2]
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  Age  \
# 177            0      129            110             46      130  67.1   26
# 445            0      180             78             63       14  59.4   25
#
#      Diabetes Pedigree Index
# 177                    0.319
# 445                    2.420

# %%
outliers_dropped = df.drop(df.index[[177,445]])
new_plot = outliers_dropped.plot.scatter(x='BMI',
                                         y='Diabetes Pedigree Index')

# %%
### BEGIN SOLUTION
sns.set_context('talk')
sns.pairplot(df, hue='Diabetes Pedigree Index');
### END SOLUTION

# %%
X = df.iloc[:,:-1]
Y = df.iloc[:,-1]
X.shape,Y.shape
# Out:
# ((768, 7), (768,))

# %%
# sns.pairplot(data=df,x_vars=X,y_vars=Y)

# %%
df.corr()
# Out:
#                          Pregnancies   Glucose  BloodPressure  SkinThickness  \
# Pregnancies                 1.000000  0.129459       0.141282      -0.081672
# Glucose                     0.129459  1.000000       0.152590       0.057328
# BloodPressure               0.141282  0.152590       1.000000       0.207371
# SkinThickness              -0.081672  0.057328       0.207371       1.000000
# Insulin                    -0.073535  0.331357       0.088933       0.436783
# BMI                         0.017683  0.221071       0.281805       0.392573
# Age                         0.544341  0.263514       0.239528      -0.113970
# Diabetes Pedigree Index    -0.033523  0.137337       0.041265       0.183928
#
#                           Insulin       BMI       Age  Diabetes Pedigree Index
# Pregnancies             -0.073535  0.017683  0.544341                -0.033523
# Glucose                  0.331357  0.221071  0.263514                 0.137337
# ...

# %%
from scipy.stats import binom
prob = 1 - binom.cdf(56, 100, 0.5)

print(str(round(prob*100, 1))+"%")
# Out:
# 9.7%

# %%
print(binom.ppf(0.95,100,0.5)+1)
# Out:
# 59.0

# %%
mu = 50
variance = 10
sigma = math.sqrt(variance)
x = np.linspace(1, 100, 200)
plt.plot(x,stats.norm.pdf(x, mu, sigma))

mu = 60
variance = 10
sigma = math.sqrt(variance)
x = np.linspace(1, 100, 200)
plt.plot(x,stats.norm.pdf(x, mu, sigma))

plt.xlim(30,80)
plt.show()

# %%
df.hist(figsize=(20,20))
# Out:
# array([[<AxesSubplot:title={'center':'Pregnancies'}>,
#         <AxesSubplot:title={'center':'Glucose'}>,
#         <AxesSubplot:title={'center':'BloodPressure'}>],
#        [<AxesSubplot:title={'center':'SkinThickness'}>,
#         <AxesSubplot:title={'center':'Insulin'}>,
#         <AxesSubplot:title={'center':'BMI'}>],
#        [<AxesSubplot:title={'center':'Age'}>,
#         <AxesSubplot:title={'center':'Diabetes Pedigree Index'}>,
#         <AxesSubplot:>]], dtype=object)

# %%
plt.figure(figsize=(12,10))
# seaborn has an easy method to showcase heatmap
p = sns.heatmap(df.corr(), annot=True,cmap ='RdYlGn')

# %% [markdown]
# From above, the data with higly cor-related or negatively co-related is useful, Other I think we can discard

# %%
plt.figure(figsize=(40,20),dpi=90)
ax=sns.countplot(x='Glucose',data=df)
plt.xticks(rotation=90, fontsize=20)
plt.yticks(fontsize=20)
plt.xlabel('Glucose',fontsize=20)
plt.ylabel('Diabetes',fontsize=20)
plt.title('count of Glucose',fontsize=30)
plt.grid()

# %%
plt.figure(figsize=(40,20),dpi=90)
ax=sns.countplot(x='BloodPressure',data=df)
plt.xticks(rotation=90, fontsize=20)
plt.yticks(fontsize=20)
plt.xlabel('Glucose',fontsize=20)
plt.ylabel('Diabetes',fontsize=20)
plt.title('count of BloodPressure',fontsize=30)
plt.grid()

# %%
plt.figure(figsize=(40,20),dpi=90)
ax=sns.countplot(x='SkinThickness',data=df)
plt.xticks(rotation=90, fontsize=20)
plt.yticks(fontsize=20)
plt.xlabel('SkinThickness',fontsize=20)
plt.ylabel('Diabetes',fontsize=20)
plt.title('count of SkinThickness',fontsize=30)
plt.grid()

# %%
plt.figure(figsize=(40,20),dpi=90)
ax=sns.countplot(x='Age',data=df)
plt.xticks(rotation=90, fontsize=20)
plt.yticks(fontsize=20)
plt.xlabel('Age',fontsize=20)
plt.ylabel('Diabetes',fontsize=20)
plt.title('count of Age',fontsize=30)
plt.grid()
